# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPool2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets.mnist import load_data
from tensorflow.keras.preprocessing.image import load_img, ImageDataGenerator, img_to_array
from tensorflow.keras.models import load_model


from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import seaborn as sns

# %%
model = load_model('catdog.h5')

# %%
testImg = load_img('./data/image/고양이test.png', target_size = (98,98))
testImg
# Out:
# <PIL.Image.Image image mode=RGB size=98x98>

# %%
testArr = img_to_array(testImg)/255.0
testArr
# Out:
# array([[[0.4745098 , 0.45490196, 0.40784314],
#         [0.6666667 , 0.64705884, 0.6       ],
#         [0.7137255 , 0.6784314 , 0.63529414],
#         ...,
#         [0.69803923, 0.6784314 , 0.6313726 ],
#         [0.5529412 , 0.53333336, 0.49019608],
#         [0.6745098 , 0.654902  , 0.60784316]],
#
#        [[0.6784314 , 0.6392157 , 0.5921569 ],
#         [0.6039216 , 0.56078434, 0.5137255 ],
#         [0.80784315, 0.7882353 , 0.74509805],
#         ...,
#         [0.6745098 , 0.654902  , 0.60784316],
#         [0.5921569 , 0.5686275 , 0.54509807],
#         [0.5803922 , 0.56078434, 0.5137255 ]],
#
#        [[0.73333335, 0.69411767, 0.6431373 ],
#         [0.68235296, 0.6509804 , 0.6       ],
#         [0.7058824 , 0.68235296, 0.63529414],
#         ...,
#         [0.6431373 , 0.62352943, 0.5764706 ],
#         [0.6745098 , 0.6431373 , 0.5882353 ],
#         [0.6392157 , 0.59607846, 0.5568628 ]],
#
#        ...,
#
#        [[0.70980394, 0.6745098 , 0.627451  ],
#         [0.4       , 0.36078432, 0.34901962],
#         [0.627451  , 0.6039216 , 0.5803922 ],
#         ...,
#         [0.34901962, 0.30980393, 0.29411766],
#         [0.5058824 , 0.49019608, 0.45882353],
#         [0.4862745 , 0.45882353, 0.42352942]],
#
#        [[0.6509804 , 0.6117647 , 0.5686275 ],
#         [0.53333336, 0.5058824 , 0.45882353],
#         [0.42745098, 0.4117647 , 0.38039216],
#         ...,
#         [0.42745098, 0.39215687, 0.35686275],
#         [0.5568628 , 0.53333336, 0.50980395],
#         [0.4745098 , 0.45490196, 0.44705883]],
#
#        [[0.62352943, 0.53333336, 0.45882353],
#         [0.87058824, 0.7647059 , 0.69803923],
#         [0.4862745 , 0.4       , 0.38039216],
#         ...,
#         [0.5254902 , 0.49803922, 0.46666667],
#         [0.9098039 , 0.6666667 , 0.5176471 ],
#         [0.3764706 , 0.3529412 , 0.33333334]]], dtype=float32)

# %%
pred = model.predict(testArr.reshape(1,98,98,3))
pred.argmax(axis = 1)
# Out:
# 1/1 [==============================] - 0s 130ms/step
# array([1], dtype=int64)
