# %%
from tensorflow.keras.applications import vgg16
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
modelVgg16 = vgg16.VGG16()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467096/553467096 [==============================] - 197s 0us/step

# %%
modelVgg16.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 138357544 (527.79 MB)
# Trainable params: 138357544 (527.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
testImg = load_img('./data/image/고양이test.png', target_size = (224,224))
testImg
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
imgArr = img_to_array(testImg)
imgArr
# Out:
# array([[[138., 133., 121.],
#         [162., 156., 144.],
#         [170., 165., 153.],
#         ...,
#         [156., 151., 138.],
#         [164., 159., 146.],
#         [149., 144., 131.]],
#
#        [[185., 177., 166.],
#         [152., 144., 132.],
#         [179., 170., 159.],
#         ...,
#         [153., 148., 135.],
#         [154., 149., 137.],
#         [166., 162., 150.]],
#
#        [[177., 168., 156.],
#         [178., 169., 157.],
#         [170., 161., 149.],
#         ...,
#         [138., 133., 123.],
#         [134., 130., 118.],
#         [125., 118., 110.]],
#
#        ...,
#
#        [[181., 167., 154.],
#         [188., 172., 154.],
#         [180., 168., 149.],
#         ...,
#         [125., 121., 107.],
#         [ 92.,  88.,  81.],
#         [109., 106., 100.]],
#
#        [[182., 164., 145.],
#         [210., 188., 165.],
#         [201., 179., 159.],
#         ...,
#         [143., 124., 106.],
#         [101.,  97.,  89.],
#         [ 95.,  89.,  87.]],
#
#        [[155., 131., 117.],
#         [230., 199., 172.],
#         [243., 214., 189.],
#         ...,
#         [137., 119., 106.],
#         [112., 105.,  98.],
#         [101.,  94.,  92.]]], dtype=float32)

# %%
imgArr.shape
# Out:
# (224, 224, 3)

# %%
pred = modelVgg16.predict(vgg16.preprocess_input(imgArr.reshape(1,224,224,3)))
# Out:
# 1/1 [==============================] - 0s 267ms/step

# %%
vgg16.decode_predictions(pred)
# Out:
# [[('n02123159', 'tiger_cat', 0.419936),
#   ('n15075141', 'toilet_tissue', 0.13136473),
#   ('n02123045', 'tabby', 0.08771064),
#   ('n03887697', 'paper_towel', 0.037617337),
#   ('n02113023', 'Pembroke', 0.03390011)]]

# %%
testImg = load_img('./data/image/test.jpg', target_size = (224,224))
testImg
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
imgArr = img_to_array(testImg)
imgArr
# Out:
# array([[[  1.,  76.,   7.],
#         [  1.,  76.,   7.],
#         [  2.,  77.,   8.],
#         ...,
#         [ 66., 121.,  17.],
#         [ 68., 123.,  19.],
#         [ 74., 130.,  23.]],
#
#        [[  1.,  76.,   7.],
#         [  1.,  76.,   7.],
#         [  2.,  77.,   8.],
#         ...,
#         [ 66., 121.,  17.],
#         [ 68., 123.,  19.],
#         [ 74., 130.,  23.]],
#
#        [[  1.,  76.,   7.],
#         [  1.,  76.,   7.],
#         [  2.,  77.,   8.],
#         ...,
#         [ 66., 121.,  17.],
#         [ 68., 123.,  19.],
#         [ 74., 130.,  23.]],
#
#        ...,
#
#        [[ 86., 121.,  55.],
#         [ 89., 121.,  58.],
#         [ 89., 121.,  58.],
#         ...,
#         [110., 149., 105.],
#         [107., 147.,  94.],
#         [ 95., 140.,  75.]],
#
#        [[ 86., 121.,  55.],
#         [ 89., 121.,  58.],
#         [ 89., 121.,  58.],
#         ...,
#         [110., 149., 105.],
#         [107., 147.,  94.],
#         [ 95., 140.,  75.]],
#
#        [[ 87., 122.,  56.],
#         [ 89., 121.,  58.],
#         [ 89., 121.,  58.],
#         ...,
#         [112., 149., 108.],
#         [107., 147.,  95.],
#         [ 95., 139.,  76.]]], dtype=float32)

# %%
pred = modelVgg16.predict(vgg16.preprocess_input(imgArr.reshape(1,224,224,3)))
vgg16.decode_predictions(pred)
# Out:
# 1/1 [==============================] - 0s 301ms/step
# [[('n02127052', 'lynx', 0.70554376),
#   ('n02123394', 'Persian_cat', 0.24343604),
#   ('n02123159', 'tiger_cat', 0.027281476),
#   ('n02123045', 'tabby', 0.008028062),
#   ('n02124075', 'Egyptian_cat', 0.0042471625)]]

# %%
testImg = load_img('./data/image/축구공.jpg', target_size = (224,224))
testImg
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
imgArr = img_to_array(testImg)
imgArr
# Out:
# array([[[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        ...,
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]],
#
#        [[255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.],
#         ...,
#         [255., 255., 255.],
#         [255., 255., 255.],
#         [255., 255., 255.]]], dtype=float32)

# %%
pred_2 = modelVgg16.predict(vgg16.preprocess_input(imgArr.reshape(1,224,224,3)))
vgg16.decode_predictions(pred_2)
# Out:
# 1/1 [==============================] - 0s 267ms/step
# [[('n04254680', 'soccer_ball', 0.79791236),
#   ('n03720891', 'maraca', 0.10146369),
#   ('n04540053', 'volleyball', 0.072130725),
#   ('n04118538', 'rugby_ball', 0.0077651734),
#   ('n09229709', 'bubble', 0.0059960624)]]
