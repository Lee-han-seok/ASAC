# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.pipeline import make_pipeline
from scikeras.wrappers import KerasRegressor

# %%
boston = pd.read_csv('data/boston.csv', index_col = 'Unnamed: 0')
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 1  396.90   4.98  24.0
# 2  396.90   9.14  21.6
# 3  392.83   4.03  34.7
# 4  394.63   2.94  33.4
# 5  396.90   5.33  36.2

# %%
x_data = boston.iloc[:,:-1].values
y_data = boston.iloc[:,-1].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 x_data = boston.iloc[:,:-1].values
#       2 y_data = boston.iloc[:,-1].values
#
# NameError: name 'boston' is not defined

# %%
def createModel():
    dense = Dense(units = 1, input_dim = 13)
    model = Sequential([dense])
    model.compile(loss = 'mse', optimizer = Adam(0.1))
    return model

# %%
kcf = KerasRegressor(model = createModel, epochs = 500, verbose = 1)

# %%
pmodel = make_pipeline(MinMaxScaler(), kcf)
pmodel.fit(x_data, y_data)
# Out:
# Epoch 1/500
# 16/16 [==============================] - 1s 2ms/step - loss: 422.7576
# Epoch 2/500
# 16/16 [==============================] - 0s 2ms/step - loss: 208.2858
# Epoch 3/500
# 16/16 [==============================] - 0s 1ms/step - loss: 136.6077
# Epoch 4/500
# 16/16 [==============================] - 0s 1ms/step - loss: 116.6862
# Epoch 5/500
# 16/16 [==============================] - 0s 2ms/step - loss: 101.2305
# Epoch 6/500
# 16/16 [==============================] - 0s 1ms/step - loss: 88.6526
# Epoch 7/500
# 16/16 [==============================] - 0s 1ms/step - loss: 78.9159
# Epoch 8/500
# 16/16 [==============================] - 0s 1ms/step - loss: 71.5314
# Epoch 9/500
# 16/16 [==============================] - 0s 1ms/step - loss: 65.6244
# Epoch 10/500
# 16/16 [==============================] - 0s 1ms/step - loss: 61.5291
# Epoch 11/500
# 16/16 [==============================] - 0s 2ms/step - loss: 58.3025
# Epoch 12/500
# ...

# %%
pmodel.predict(x_data[0].reshape(1,-1))
# Out:
# 1/1 [==============================] - 0s 87ms/step
# array([30.215223], dtype=float32)
