# %% [markdown]
# #[1] 알고리즘

# %% [markdown]
# ## [1-1] 지도학습  >  분류

# %% [markdown]
# - 로지스틱 회귀
# - KNN
# - 나이브베이즈
# - 결정트리
# - SVM - SVC
# - 앙상블
#     - 보팅
#     - 배깅 - 랜덤포레스트
#     - 부스팅
#         - XGboost
#         - lightgbm
#         - CatBoost(써드파트)
#     - 스태킹

# %% [markdown]
# ### 오차행렬
#
# - 정확도, 정밀도, 재현율, F1-Score 등

# %% [markdown]
# ### 로그 손실

# %% [markdown]
# ### ROC AUC

# %% [markdown]
# ## [1-2] 지도학습 > 회귀

# %% [markdown]
# - 선형회귀
# - KNN
# - Lasso
# - Ridge
# - ElasticNet
# - 결정트리
# - SVM
# - 앙상블

# %% [markdown]
# ### 손실함수

# %% [markdown]
# ## [1-3] 비지도학습 > 군집

# %% [markdown]
# - K-MEAN (거리 기반)
# - Mean-Shift (밀도 기반)
# - GMM (확률 기반)
# - DBSCAN (밀도기반, 기하학)

# %% [markdown]
# ## [1-4] 비지도학습 > 차원축소

# %% [markdown]
# - PCA, LDA, SVD, NMF

# %% [markdown]
# # [2] 데이터 준비 - 피처엔지니어링 (특성 공학) & EDA

# %% [markdown]
# ## [2-1] 데이터 인코딩
#
# - LabelEncoder, OrdinalEncoder, OneHotEncoder, 써드파트(category_encoders)

# %% [markdown]
# ## [2-2] 피처 스케일링
#
# - StandardScaker, ....

# %% [markdown]
# ## [2-3] 피처 처리
#
# - 피처 제거
# - 결측치 제거
# - 이상치 제거
# - 피처 생성

# %% [markdown]
# # [3] 학습

# %% [markdown]
# ## [3-1] 기본학습

# %% [markdown]
# ## [3-2] 교차 검증

# %% [markdown]
# ### K-폴드
# - 정답 분포가 균형 할 때

# %% [markdown]
# ### 층화 K-폴드
#
# - 정답 분포가 불균형 할 때

# %% [markdown]
# ## [3-3] 예측

# %% [markdown]
# # [4] 성능 평가

# %% [markdown]
# ## [4-1] 분류

# %% [markdown]
# ### 오차행렬

# %% [markdown]
# ### 로그손실

# %% [markdown]
# ### ROC-AUC

# %% [markdown]
# ## [4-2] 회귀

# %% [markdown]
# ### 손실함수

# %% [markdown]
# ## [4-3] 군집

# %% [markdown]
# # [5] 최적화

# %% [markdown]
# ## [5-1] 하이퍼 파라미터 튜닝

# %% [markdown]
# ### 그리드 서치

# %% [markdown]
# ### 랜덤 서치

# %% [markdown]
# ### 베이지안 최적화

# %% [markdown]
# # [6] 파이프라인

# %% [markdown]
# ## 서드파트

# %% [markdown]
# ## 파이캐럿

# %% [markdown]
# ## AutoML

# %% [markdown]
# # [7] 모델 덤프 및 서빙(인프라 구축 및 MLOps)
